# %%
from Functions_HO import *
import importlib
importlib.reload(Functions_HO)
# Out:
# <module 'Functions_HO' from 'c:\\Users\\sahil\\Git\\1D-Quantum-harmonic-oscillator\\Functions_HO.py'>

# %%
x_discrete, delta=discretization(1001,-15,15) #input (L, x_min, x_max ) returns  x, dx
wf, norm =Initial_wavefunction(1,1,x_discrete)
potential=discrete_Potential(1, x_discrete)
U_matrix=approximate_time_step(0.00025, potential, delta)
# Out:
# Spacing dx: 0.03
