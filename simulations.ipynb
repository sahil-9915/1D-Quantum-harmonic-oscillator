# %%
import harmonic_oscillator_qm as hoqm
import importlib
importlib.reload(hoqm)
from harmonic_oscillator_qm import *

# %%
ho_temp=QuantumSimulator(1001,-15,15)
ho_temp.Initial_wavefunction(1,1)
ho_temp.discrete_Potential(1)
ts=ho_temp.approximate_time_step(0.0001)
tst=np.conj(ts.T)
k=tst@ts
print(k)
# Out:
# [[ 1.00000000e+00+0.00000000e+00j  1.73472348e-18+0.00000000e+00j
#   -4.33680869e-19+1.08420217e-19j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 1.73472348e-18+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#    1.73472348e-18-6.93889390e-18j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [-4.33680869e-19-1.08420217e-19j  1.73472348e-18+6.93889390e-18j
#    1.00000000e+00+0.00000000e+00j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  ...
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  1.00000000e+00+0.00000000e+00j
#    0.00000000e+00+6.93889390e-18j  0.00000000e+00+1.08420217e-19j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  0.00000000e+00-6.93889390e-18j
# ...
