# %%
import harmonic_oscillator_qm as hoqm
import importlib
importlib.reload(hoqm)
from harmonic_oscillator_qm import *

# %%
ho_temp=QuantumSimulator(1001,-15,15)
ho_temp.Initial_wavefunction(2,1)
ho_temp.discrete_Potential(1)
evolved_temp=ho_temp.approximate_evolution(0.00025,10) #returns evolved wavefunction
#ho_temp.plot_probability_density()
ho_temp.plot_expectation_x()
