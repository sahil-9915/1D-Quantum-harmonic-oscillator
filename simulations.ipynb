# %%
import QuantumSimulator as sim
import importlib
importlib.reload(sim)
from QuantumSimulator import *

# %%
harmonic_oscillator=Quantum_numerical_simulator(1001,-15,15)  # creates discrete space for simulation
harmonic_oscillator.Initial_gaussian_wavefunction(1,0) # input sigma and x0 to define the initial Gaussian wave packet formula; x0 = 0 (centred at origin)
harmonic_oscillator.discrete_Potential(2) # input the force constant for oscillator
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,0) #input tau and time -> returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,2) #plot probability density at t=2
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,4) #plot probability density at t=4
harmonic_oscillator.plot_probability_density()

# %%
harmonic_oscillator.plot_expectation_x()

# %%
harmonic_oscillator.plot_expectation_var()

# %%
harmonic_oscillator.Initial_wavefunction(1,1) # Wave packet centred at 1
harmonic_oscillator.discrete_Potential(2) 
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,0) #returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,2) 
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,4) 
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,6) 
harmonic_oscillator.plot_probability_density()

# %%
harmonic_oscillator.plot_expectation_x()

# %%
harmonic_oscillator.plot_expectation_var()

# %%
harmonic_oscillator.Initial_wavefunction(1,1) # Wave packet centred at 1
harmonic_oscillator.discrete_Potential(1) #coherent state -> wave packet should maintain shape and oscillate along axis
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,0) #returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,2) #returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,4) #returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
evolved_temp=harmonic_oscillator.approximate_evolution(0.00025,6) #returns evolved wavefunction
harmonic_oscillator.plot_probability_density()

# %%
harmonic_oscillator.plot_expectation_x()

# %%
harmonic_oscillator.plot_expectation_var()
